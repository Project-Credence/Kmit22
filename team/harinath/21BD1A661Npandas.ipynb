# %% [markdown]
# uplaoding the dataset

# %%
import pandas as pd
from google.colab import files
up=files.upload()
# Out:
#      <input type="file" id="files-1a1ddbe1-997a-4ec9-98e9-342bfdc2d030" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a1ddbe1-997a-4ec9-98e9-342bfdc2d030">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
ind=pd.read_csv(io.BytesIO(up["India_GDP_1960-2022.csv"]),index_col=0)
ind
# Out:
#      India GDP - Historical Data India GDP - Historical Data.1  \
# NaN                         Year            GDP in (Billion) $
# 0.0                         2021                        3173.4
# 1.0                         2020                       2667.69
# 2.0                         2019                       2831.55
# 3.0                         2018                       2702.93
# ...                          ...                           ...
# 57.0                        1964                         56.48
# 58.0                        1963                         48.42
# 59.0                        1962                         42.16
# 60.0                        1961                         39.23
# 61.0                        1960                         37.03
#
#      India GDP - Historical Data.2 India GDP - Historical Data.3
# NaN           Per Capita in rupees                      Growth %
# 0.0                         182160                          8.95
# ...

# %%
ind.head(20)
# Out:
#      India GDP - Historical Data India GDP - Historical Data.1  \
# NaN                         Year            GDP in (Billion) $
# 0.0                         2021                        3173.4
# 1.0                         2020                       2667.69
# 2.0                         2019                       2831.55
# 3.0                         2018                       2702.93
# 4.0                         2017                       2651.47
# 5.0                         2016                        2294.8
# 6.0                         2015                       2103.59
# 7.0                         2014                       2039.13
# 8.0                         2013                       1856.72
# 9.0                         2012                       1827.64
# 10.0                        2011                       1823.05
# 11.0                        2010                       1675.62
# 12.0                        2009                       1341.89
# ...

# %%
ind.head()
# Out:
#     India GDP - Historical Data India GDP - Historical Data.1  \
# NaN                        Year            GDP in (Billion) $
# 0.0                        2021                        3173.4
# 1.0                        2020                       2667.69
# 2.0                        2019                       2831.55
# 3.0                        2018                       2702.93
#
#     India GDP - Historical Data.2 India GDP - Historical Data.3
# NaN          Per Capita in rupees                      Growth %
# 0.0                        182160                          8.95
# 1.0                        154640                          -6.6
# 2.0                        165760                          3.74
# 3.0                        159840                          6.45

# %%
ind.tail()
# Out:
#      India GDP - Historical Data India GDP - Historical Data.1  \
# 57.0                        1964                         56.48
# 58.0                        1963                         48.42
# 59.0                        1962                         42.16
# 60.0                        1961                         39.23
# 61.0                        1960                         37.03
#
#      India GDP - Historical Data.2 India GDP - Historical Data.3
# 57.0                          9280                          7.45
# 58.0                          8080                          5.99
# 59.0                          7200                          2.93
# 60.0                          6800                          3.72
# 61.0                          6560                             0

# %%
ind.tail(20)
# Out:
#      India GDP - Historical Data India GDP - Historical Data.1  \
# 42.0                        1979                        152.99
# 43.0                        1978                         137.3
# 44.0                        1977                        121.49
# 45.0                        1976                        102.72
# 46.0                        1975                         98.47
# 47.0                        1974                         99.53
# 48.0                        1973                         85.52
# 49.0                        1972                         71.46
# 50.0                        1971                         67.35
# 51.0                        1970                         62.42
# 52.0                        1969                         58.45
# 53.0                        1968                         53.09
# 54.0                        1967                         50.13
# 55.0                        1966                         45.87
# ...

# %%
ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 63 entries, nan to 61.0
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   India GDP - Historical Data    63 non-null     object
#  1   India GDP - Historical Data.1  63 non-null     object
#  2   India GDP - Historical Data.2  63 non-null     object
#  3   India GDP - Historical Data.3  63 non-null     object
# dtypes: object(4)
# memory usage: 2.5+ KB

# %%
ind.describe()
# Out:
#        India GDP - Historical Data India GDP - Historical Data.1  \
# count                           63                            63
# unique                          63                            63
# top                           Year            GDP in (Billion) $
# freq                             1                             1
#
#        India GDP - Historical Data.2 India GDP - Historical Data.3
# count                             63                            63
# unique                            60                            61
# top                            27680                          7.86
# freq                               2                             2
